# %%
ENGINEER = "San Jose"
STUDENT_ID = "TUPM-25-0789"
SEED_NUM = int(STUDENT_ID[-1])
print(f"System Initialized for: {ENGINEER}")
print(f"Algorithmic Seed Value: {SEED_NUM}")
# Out:
# System Initialized for: San Jose
# Algorithmic Seed Value: 9

# %%
actual = 0.1 + 0.2
print(f"Python stores: {actual}")
if actual == 0.3:
    print("Result: Perfect Match")
else:
    print("Result : PRECISION ERROR (Binary Artifact)")
# Out:
# Python stores: 0.30000000000000004
# Result : PRECISION ERROR (Binary Artifact)

# %%
first_letter = ENGINEER[0]
byte_val = ord(first_letter)
print(f"Character: {first_letter}")
print(f"ASCII Value: {byte_val}")
print(f"Next in Sequence: {chr(byte_val + 1)}")
# Out:
# Character: S
# ASCII Value: 83
# Next in Sequence: T

# %%
raw_in = input("Enter Name (add messy spaces): ")
clean_in = raw_in.strip().upper()
print(f"Original: '{raw_in}' | Cleaned; '{clean_in}'")
# Out:
# Original: 'lennard    ' | Cleaned; 'LENNARD'

# %%
user_input = input("Press Enter (leave empty) or type data: ")
if user_input:
    print(f"Data Detected: {user_input}")
else:
    print(f"ALERT: No data stream detected.")
# Out:
# Data Detected: gegegeg

# %%
campus = STUDENT_ID[0:4]
unique_id = STUDENT_ID[8:]
tokens = STUDENT_ID.split("-")
print(f"Campus Code: {campus}")
print(f"Unique Sequence: {unique_id}")
print(f"Token List: {tokens}")
# Out:
# Campus Code: TUPM
# Unique Sequence: 0789
# Token List: ['TUPM', '25', '0789']

# %%
if SEED_NUM % 2 == 0:
    priority = "LOW (Even Seed)"
else:
    priority = "HIGH (Odd Seed)"
print(f"System Priority: {priority}")
# Out:
# System Priority: HIGH (Odd Seed)

# %%
limit = (SEED_NUM * 10) + 20
print (f"---SAFETY LIMIT: {limit} ---")
val = int(input("(Enter Sensor Reading: "))
if val > limit:
    print("ALert: Over LIMIT")
elif val < 5:
    print("ALERT: Low Signal")
else:
    print("STATUS: Nominal")
# Out:
# ---SAFETY LIMIT: 110 ---
# STATUS: Nominal

# %%
try:
    voltage = int(input("Enter Voltage (Numeric): "))
    print(f"Voltage Captured: {voltage}V")
except ValueError:
    print("SYSTEM ERROR: Input msut be numeric. Resetting to 0.")
    voltage = 0
print(f"System continues... Current Voltage: {voltage}")
# Out:
# Voltage Captured: 20V
# System continues... Current Voltage: 20

# %%
has_power = False
if has_power and (10 / 0 == 0):
    print("System On")
else:
    print("System Off (Short-Circuit Triggered)")
# Out:
# System Off (Short-Circuit Triggered)

# %%
loops = SEED_NUM + 3
print(f"--- RUNNING {loops} CYCLES ---")
for i in range(1, loops +1):
    print(f"Cycle {i}/{loops} ...Complete")
# Out:
# --- RUNNING 12 CYCLES ---
# Cycle 1/12 ...Complete
# Cycle 2/12 ...Complete
# Cycle 3/12 ...Complete
# Cycle 4/12 ...Complete
# Cycle 5/12 ...Complete
# Cycle 6/12 ...Complete
# Cycle 7/12 ...Complete
# Cycle 8/12 ...Complete
# Cycle 9/12 ...Complete
# Cycle 10/12 ...Complete
# Cycle 11/12 ...Complete
# Cycle 12/12 ...Complete

# %%
rows = int(tokens[2][0])
cols = int(tokens[2][-1])
print(f"Generating {rows}x{cols} Matrix: ")
for r in range(rows):
    for c in range(cols):
        print("#", end=" ")
    print()
# Out:
# Generating 0x9 Matrix:

# %%
while True:
    pwd = input("Type 'ADMIN' to exit: ")
    if pwd == "ADMIN":
        print("Unlocked.")
    else:
        print("Access Denied.")
# Out:
# Unlocked.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[62], line 2
#       1 while True:
# ----> 2     pwd = input("Type 'ADMIN' to exit: ")
#       3     if pwd == "ADMIN":
#       4         print("Unlocked.")
#
# File c:\Users\leand\Lab2_Fundamentals_SanJose\.venv\Lib\site-packages\ipykernel\kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File c:\Users\leand\Lab2_Fundamentals_SanJose\.venv\Lib\site-packages\ipykernel\kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# -> 1448     raise KeyboardInterrupt(msg) from None
#    1449 except Exception:
#    1450     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
A = byte_val
B = SEED_NUM
C = loops
verification_hash = (A * B) - C
print(f"User: {ENGINEER}")
print(f"Forensic Signature: {verification_hash}")
# Out:
# User: San Jose
# Forensic Signature: 735
